# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammadi-Nilofer/EDA-Assignments/blob/EDA/Iris_Datavisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization on Iris dataset

# %% [markdown]
# **Context**
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper,It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# **Problem Statement:**
#
# The Iris dataset contains measurements of sepal length, sepal width, petal length, and petal width for three species of iris flowers (Setosa, Versicolor, and Virginica). We want to understand the underlying patterns and relationships within this data.
#
# **Objective:**
#
# Perform Exploratory Data Analysis (EDA) on the Iris dataset to gain insights into the distribution of features, relationships between variables, and potential differences between the three iris species. This will involve visualizing the data through various plots, calculating descriptive statistics, and identifying any significant trends or outliers.

# %% [markdown]
# **Data dictionary**
#
# Id
#
#
# SepalLengthCm -
# Length of the sepal (in cm)
#
#
# SepalWidthCm-
# Width of the sepal (in cm)
#
#
# PetalLengthCm-
# Length of the petal (in cm)
#
#
# PetalWidthCm-
# Width of the petal (in cm)
#
#
# Species-
# Species name

# %% [markdown]
# # Importing all necessary libraries

# %%
import pandas as pd  # for data manipulation
import numpy as np  # for numerical operations
import matplotlib.pyplot as plt  # for data visualization
import seaborn as sns  # for data visualization

# %% [markdown]
# #Loading the data

# %%
df=pd.read_csv('Iris.csv')

# %%
# first five rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# last 5 rows
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# Checking the no. of rows and columns

df.shape
# Out:
# (150, 6)

# %%
df.info()       #checking the info and datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# **Checking Null values**

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **Observation:** There are no null values.

# %% [markdown]
# **Checking for duplicate values**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observation:**  There are no duplicate values in the data.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe(include='object')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %% [markdown]
# **Observation: **  The most frequent species is iris-setosa.

# %% [markdown]
# #Exploratory data analysis(EDA)

# %%
# Univariate analysis

sns.countplot(df['Species'])
plt.show()

# %%
# Calculate the frequency of each species
species_counts = df['Species'].value_counts()

# Create the pie chart using the counts and labels
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Iris Species')
plt.show()

# %% [markdown]
# **Observation:**  The pie chart shows that each of the three Iris species – Setosa, Versicolor, and Virginica – is represented equally in the dataset

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # 1. What is the distribution of sepal lengths and widths among the Iris species?

# %%
sns.histplot(df['SepalLengthCm'])
plt.title('Distribution of Sepal Length')
plt.show()

# %% [markdown]
# **Observation:** , the histplot of sepal length suggests that it is roughly normally distributed, with most flowers having sepal lengths between 5.5 and 6.0 cm. The data spans a range of 4.0 cm to 8.0 cm, and there might be a few potential outliers towards the higher end.

# %%
# Distribution of Sepal width

sns.histplot(df['SepalWidthCm'])
plt.title('Distribution of Sepal Width')
plt.show()

# %% [markdown]
# **Observation:** The histplot of sepal length suggests that,most flowers having sepal width between 2.5 and 3.5 cm. The highest sepal width is around 3cm.

# %%
# Create box plots for sepal length
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
plt.title('Distribution of Sepal Length among Iris Species')
plt.show()

# Create box plots for sepal width
sns.boxplot(x='Species', y='SepalWidthCm', data=df)
plt.title('Distribution of Sepal Width among Iris Species')
plt.show()

# %% [markdown]
# Interpreting the Box Plots for Sepal Length and Width:
#
# **Sepal Length:**
#
# * Setosa: The Setosa species has the shortest sepal length, with a median around 5.0 cm and a relatively narrow IQR. There are no outliers for this species.
# * Versicolor: The Versicolor species has a slightly longer sepal length compared to Setosa, with a median around 6.0 cm and a wider IQR. There are a few potential outliers towards the higher end of the sepal length range.
# *Virginica: The Virginica species has the longest sepal length, with a median around 6.5 cm and the widest IQR. It also has a few potential outliers towards the higher end of the sepal length range.
#
# **Sepal Width:**
#
# * Setosa: The Setosa species has the widest sepal width, with a median around 3.5 cm and a relatively wide IQR. There are no outliers for this species.
# * Versicolor: The Versicolor species has a slightly narrower sepal width compared to Setosa, with a median around 2.8 cm and a narrower IQR. There are no outliers for this species.
# *Virginica: The Virginica species has the narrowest sepal width, with a median around 3.0 cm and a relatively narrow IQR. There might be a few potential outliers towards the lower end of the sepal width range.
#
# Overall Interpretation:
#
# * The box plots reveal clear differences in the distribution of sepal length and width among the Iris species.
# * Setosa tends to have shorter sepal lengths and wider sepal widths compared to the other two species.
# * Versicolor and Virginica have longer sepal lengths and narrower sepal widths, with Virginica generally having the longest sepal lengths.
# * There are a few potential outliers for sepal length in Versicolor and Virginica, and potentially for sepal width in Virginica.

# %% [markdown]
# # 2. How does the petal length vary across different Iris species?

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.boxplot(x='Species', y='PetalLengthCm', data=df)
plt.title('Distribution of Petal Length among Iris Species')
plt.show()

# %% [markdown]
# **Interpreting the boxplot for petal length**
#
# Setosa: The species setosa has the shortest petal length with a median around 1.5 and a relatively narrow IQR. There are some outliers for petal length in setosa.
#
# Versicolor: The Versicolor species has a significantly longer petal length compared to Setosa, with a median around 4.5 cm and a wider IQR. There are a few potential outliers towards the lower end of the petal length range.
#
# Virginica: The Virginica species has the longest petal length, with a median around 5.5 cm and the widest IQR. It also has no outliers.

# %% [markdown]
# # 3. Is there a relationship between sepal length and petal length?

# %%
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', hue='Species', data=df)
plt.title('Relationship between Sepal Length and Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# %% [markdown]
# **Interpreting the scatterplot for relationship between sepal length and petal length:**
#
# * The scatterplot indicates a positive relationship between sepal length and petal length for Iris flowers.
# * This relationship is particularly strong for the Setosa species.
# * Versicolor and Virginica species exhibit some overlap, but Virginica generally has longer sepal and petal lengths.

# %% [markdown]
# #  4. How does the petal width vary across different Iris species?

# %%
sns.boxplot(x='Species', y='PetalWidthCm', data=df)
plt.title('Distribution of Petal Width among Iris Species')
plt.show()

# %% [markdown]
# Interpreting the boxplot for petal width
#
# Setosa: The species setosa has the shortest petal width with a median ;ess than 0.5 and a relatively narrow IQR. There are some outliers towards upper end for petal width in setosa.
#
# Versicolor: The Versicolor species has a significantly longer petal width compared to Setosa, with a median around 1.4 cm and a wider IQR. There are no outliers.
#
# Virginica: The Virginica species has the longest petal width, with a median around 2 cm and the widest IQR. It also has no outliers.
#
# **The differences in petal width among the Iris species- Setosa has the narrowest petals, followed by Versicolor, and Virginica has the widest petals.**

# %% [markdown]
# # 5. Are there any patterns observable in the pairwise relationships between features(sepal length, sepal width, petal length, petal width)?

# %%
# Pairplot of sepal length, sepal width, petal length, petal width
sns.pairplot(df, hue='Species')
plt.show()

# %% [markdown]
# **Interpreting the pairplot:**
#
# * The pair plot reveals several interesting patterns in the pairwise relationships between features in the Iris dataset.
# * There are strong positive correlations between sepal length, petal length, and petal width.
# * There's a weak negative correlation between sepal width and petal length/width.
# * The relationships between features are often species-specific, with Setosa having distinct characteristics compared to Versicolor and Virginica.

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Heatmap for correlation

sns.heatmap(df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Interpreting the correlation heatmap:**
#
# * Petal length and width are highly positively correlated(.096).
#
# * Sepal length is positively correlated with petal length and width(0.87 and 0.82) respectively.
# * Sepal width shows a negative correlation with petal length and width(-0.43 and -0.37) respectively.
# * Sepal length and sepal width have a weak correlation(-0.11).

# %% [markdown]
# #  6. Can we distinguish between Iris species based on sepal and petal measurements?

# %%
df_1=df.drop('Id',axis=1)
species_means = df_1.groupby('Species').mean()

# %%
species_means
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %%
species_means.plot(kind='bar', figsize=(10, 6))  # Adjust figsize as needed
plt.title('Mean Sepal and Petal Measurements by Species')
plt.ylabel('Measurement (cm)')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.legend(title='Feature')
plt.show()

# %% [markdown]
# **Interpreting the barchart**
#
# * Petal Length & Width: Most distinguishing features, showing clear differences between species. Setosa has the smallest, Virginica the largest, and Versicolor in between.
# * Sepal Length: Provides additional clues, with Virginica having the longest, followed by Versicolor, then Setosa.
# * Sepal Width: Less informative for species differentiation.

# %% [markdown]
# # Conclusion:
#
# **Setosa:**
#
# * Petal Length: Significantly shorter than other species, typically less than 2 cm.
# * Petal Width: Narrowest among all species, usually less than 0.5 cm.
# * Sepal Length: Shortest among all species.
# * Sepal Width: Widest among all species, but overlaps with other species.
#
# **Versicolor:**
#
# * Petal Length: Intermediate length, typically between 3 cm and 5 cm.
# * Petal Width: Wider than Setosa, but narrower than Virginica, usually between 1 cm and 1.8 cm.
# * Sepal Length: Intermediate length, between Setosa and Virginica.
# * Sepal Width: Similar to Virginica, making it less useful for differentiation.
#
# **Virginica:**
#
# * Petal Length: Longest among all species, typically greater than 5 cm.
# * Petal Width: Widest among all species, usually greater than 1.8 cm.
# * Sepal Length: Longest among all species.
# * Sepal Width: Similar to Versicolor, making it less useful for differentiation.
